# %%
import os
from dotenv import load_dotenv

#load_dotenv()

#OPENAI_API_KEY = os.getenv("OPENAI_API_KEY") # (Optional), if OpenAI Model is used

MODEL = "mistral:latest" # Name of the model used by Ollama

COLLECTION_NAME = 'doc_qa_db' # Name of the Collection to be created

DIMENSION = 768 # Dimension of the embeddings

URI = 'http://localhost:19530' # Connection parameters for the Milvus Server

# %%
# Import LLM and Embeddings

from langchain_community.llms import Ollama
from langchain_community.embeddings import OllamaEmbeddings

model = Ollama(model=MODEL)
# print(model.invoke("Who is the fastest football player in the world?"))
embeddings = OllamaEmbeddings(model="mistral:latest")
# Out:
#  Determining the fastest footballer in the world can be challenging due to the lack of official speed tests during matches. However, one of the players often cited as one of the quickest is former English and Manchester City winger, Jacob Söderberg Bergström, known professionally as Jacob Bergstrom or simply Jacob. He set a world record for sprinting over 100 meters with a football in 2014, completing it in 10.39 seconds.
#
# In terms of in-game speed, Chelsea's current player, Christian Pulisic, and Manchester City's Raheem Sterling are often highlighted due to their impressive pace on the pitch.
#
# It is essential to note that these players are among the fastest, but the game requires a combination of speed, agility, acceleration, and change of direction abilities, which can sometimes be difficult to quantify accurately.

# %%
# (Optional) When you use Open AI Model, you have to parse the output

from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

chain = model | parser
chain.invoke("Tell me a joke")
# Out:
# ' Of course! Here\'s a classic one:\n\nWhy don\'t scientists trust atoms?\n\nBecause they make up everything! (Everything being the element symbol for Erbium in periodic table, which is fun to remember because it sounds like "every thing")\n\nHope that made you smile today! Let me know if you need anything else.'

# %%
# (Example) Use a PDF and split it to later save it into the Vector Store and do Question Answering with it

from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf")
pages = loader.load_and_split()
pages
# Out:
# [Document(page_content='Universität Leipzig  \nWirtschaftswissenschaftliche Fakultät  \nInstitut für Wirtschaftsinformatik  \nProf. Dr. Rainer Alt  \n \nThema  \nOptimierung Cloud -zentrierter Anwendungslandschaften durch \nApplication Portfolio Management – Herausforderungen und \nLösungen am Beispiel eines Enterprise Architecture Management \nTools   \nBachelorarbeit zur Erlangung des akademischen Grades  \nBachelor of Science – Wirtschaftsinformatik  \n \nvorgelegt von: Schmohl, Marvin   \nMatrikelnummer:  3719466  \nE-Mail-Adresse:  marvin.schmohl@gmx.de  \nTelefonnummer:  +49 176 41492574  \nAnschrift:  Steindamm 17  \n20099  Hamburg  \nLeipzig, den 30.09.2023', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 0}),
#  Document(page_content='Abstract  \nUm Anforderungen an eine moderne Anwendungslandschaft gerecht zu werden, kommt \nzunehmend Cloud Computing zum Einsatz. Trotz vieler Vorteile birgt die Technologie \ngegenüber herkömmlich betriebener Infrastruktur jedoch neue Risiken und \nHerausforderungen. Um diesen gerecht zu werden, wird Application Portfolio Management \nin der Arbeit als möglicher Lösungsansatz untersucht. Dafür wurden im Rahmen  einer \nLiteraturrecherche die Risiken und Herausforderungen bei Cloud -zentrierten \nAnwendungslandschaften identifizie rt und den Zielen und Ergebnissen von Application \nPortfolio Management gegenübergestellt. Anschließend wurde eine leitfadenorientierte \nSoftwareevaluation durchgeführt, um die Analyseergebnisse praktisch zu erproben. Dafür \nwurde ein Fragebogen entwickelt und auf ein Enterprise Architecture Management -Tool mit \nFokus auf Application Portfolio Mana gement angewandt. Die Ergebnisse zeigen, dass durch \ndie Erfassung und konsolidierte Bereitstellung von Informationen Risiken und \nHerausforderungen aus finanzieller, o perativer und strategischer Perspektive adressiert \nwerden. Dennoch stellt die Managementdisziplin keine Allgemeinlösung dar und es müssen \nzusätzliche Maßnahmen ergriffen werden, um einen sicheren und nutzenstiftenden Umga ng \nmit der Technologie zu gewährleisten.  \n \nSchlüsselwörter: Cloud Computing, Cloud -Risiken, Application Port folio \nManagement, Enterprise Architecture Management', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 1}),
#  Document(page_content='Gliederung  I \nGliederung  \nGliederung  ................................ ................................ ................................ ............................. I \nAbbildungsverzeichnis  ................................ ................................ ................................ ....... II \nTabellenverzeichnis  ................................ ................................ ................................ ..........  III \nAbkürzungsverzeichnis  ................................ ................................ ................................ ..... IV \n1 Einleitung  ................................ ................................ ................................ .....................  1 \n2 Cloud Computing  ................................ ................................ ................................ ........  3 \n2.1 Theoretische Grundlagen und Einordnung  ................................ ................................  3 \n2.1.1 Definition und Abgrenzung  ................................ ................................ ................................ ........  3 \n2.1.2 Ausprägungen von Cloud Computing  ................................ ................................ ........................  4 \n2.1.3 Einordnung in aktuelle Technologietrends  ................................ ................................ .................  5 \n2.2 Vorteile einer Cloud -zentrierten Anwendungslandschaft  ................................ .........  7 \n2.3 Risiken und Herausforderungen einer Cloud -zentrierten Anwendungslandschaft  ... 9 \n3 Application Portfolio Management  ................................ ................................ ..........  12 \n3.1 Theoretische Einführung  ................................ ................................ .........................  12 \n3.2 Einordnung  ................................ ................................ ................................ ..............  14 \n3.3 Gründe für die Einführung von APM  ................................ ................................ ...... 15 \n3.4 Ziele und Ergebnisse von Application Portfolio Management  ...............................  16 \n3.5 Anwendung von Application Portfolio Management zur Bewältigung von Risiken \nund Herausforderungen bei der Nutzung von Cloud -Diensten  ................................ ....... 18 \n4 Praktische Anwendung des Ansatzes  ................................ ................................ ....... 20 \n4.1 Vorstellung des Untersuchungsgegenstands  ................................ ...........................  20 \n4.2 Vorstellung des Evaluationsansatzes  ................................ ................................ ....... 22 \n4.3 Ergebnisse der Evaluation  ................................ ................................ .......................  24 \n4.4 Bewertung der Wirksamkeit des Ansatzes  ................................ ..............................  26 \n5 Diskussion  ................................ ................................ ................................ ...................  27 \n5.1 Diskussion der Ergebnisse  ................................ ................................ .......................  27 \n5.2 Weitere Lösungsansätze  ................................ ................................ ..........................  30 \n6 Fazit ................................ ................................ ................................ .............................  31 \nLiteraturverzeichnis  ................................ ................................ ................................ ...........  V \nAnhang  ................................ ................................ ................................ ............................. VIII  \nEhrenwörtliche Erklärung ................................ ................................ ............................. XIII', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandscha ...
#  Document(page_content='Abbildungsverzeichnis  II \n Abbildungsverzeichnis  \nAbbildung 1: Ausprägungen von Cloud Computing  ................................ .............................  5 \nAbbildung 2: Prozesslandkarte IT -Unternehmensarchitektur  ................................ .............  15 \nAbbildung 3: Gartner Magic Quadrant für Enterprise Architecture Management -Tools  ... 21 \nAbbildung 4: LeanIX Metamodell (v3) im Vergleich mit ArchiMate -Modell  ...................  22 \nAbbildung 5: Evaluationsergebnisse der Bewertungsgruppe Informationsumfang  ............  24 \nAbbildung 6: Evaluationsergebnisse der Bewertungsgruppe Funktionsumfang  .................  25 \nAbbildung 7: Vorgehensmodell für die Entwicklung einer Cloud -Strategie  ......................  30', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 3}),
#  Document(page_content='Tabellenverzeichnis  III \n Tabellenverzeichnis  \nTabelle 1: Differenzierungsmerkmale von Cloud -Services gegenüber herkömmlicher IT -\nInfrastruktur  ................................ ................................ ................................ ...................  4 \nTabelle 2: Vorteile der Nutzung von Cloud -Diensten  ................................ ...........................  7 \nTabelle 3: Risiken und Herausforderungen der Nutzung von Cloud -Diensten  .....................  9 \nTabelle 4: Unterstützung bei Cloud -Risiken durch APM  ................................ ...................  19 \nTabelle 5: Prozessschritte bei der Softwareevaluation  ................................ ........................  23', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 4}),
#  Document(page_content='Abkürzungsverzeichnis  IV \n Abkürzungsverzeichnis  \nAPM  Application Portfolio Management  \nCCCC  Cloud Computing Considerations for Companies  \nEAM  Enterprise Architecture Management  \nEOL  End-of-Life \nESG  Environmental, Social and Governance  \nIaaS Infrastructure -as-a-Service \nIoT Internet of Things  \nNIST  National Institute of Standards and Technology  \nPaaS  Platform -as-a-Service  \nPAYG  Pay-as-you-go \nSaaS  Software -as-a-Service  \nSASE  Secure Access Service Edge  \nSLA  Service Level Agreement  \nSMP  SaaS  Management  Platform  \nTRM  Technology Risk Management', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 5}),
#  Document(page_content='Einleitung  1 \n 1 Einleitung  \nIn der heutigen Ära der digitalen Transformation stehen Unternehmen vor der \nHerausforderung sich ständig wandelnder technologischer Landschaften , die sie dazu \ndrängen, ihre Geschäftsprozesse zu optimieren und agiler zu werden. Eine entscheidende \nRolle bei dieser Transformation spielen Cloud -Dienste. Sie bringen Vorteile mit sich, wie \nKosteneffizienz, hohe Flexibilität und Skalierbarkeit sowie den Zugang zu neuen \nTechnologien  (Hentschel & Leyh, 2018) . Nicht verwunderlich sind daher Prognosen, dass \nbis zum Jahr 2025 mehr als 85% aller Unternehmen ein Cloud -First-Prinzip anwenden \nwerden und die Nutzung von Cloud -Native -Architekturen und -Technologien für die \nUmsetzung digitaler Strategien  obligatorisch wird (Goasduff, 2022) . Gleichzeitig birgt die \nNutzung dieser Dienste aber auch neue Risiken und Herausforderungen gegenüber \nherkömmlich betriebenen Infrastrukturen. Diese bestehen beispielsweise in der Verletzung \nder Datensicherheit, Verstöße gegenüber Compliance -Regularien un d erhöhtem Aufwand \nbei der Migration überholter  Legacy -Anwendungen  (Hentschel & Leyh, 2018) . Vor allem \nfür große Unternehmen und Konzerne mit einer komplexen Anwendungslandschaft können \ndiese Risiken nicht immer vollständig überblickt und damit adressiert werden.  \nEine mögliche Herangehensweise zur Reduktion dieser Komplexität besteht im Einsatz von \nApplication Portfolio Management (APM). Als Teilgebiet des Enterprise Architecture \nManagements (EAM) konzentriert es sich darauf, durch systematische und strukturierte \nAnwendung entscheidungsunterstützender Prozesse die Anwendungslandschaft anhand \nverschiedener Dimensionen zu evaluieren (Simon et al., 2010) . Dadurch können \nAnwendungen rationalisiert und somit Kosten gesenkt, Transparenz geschaffen und die \nImplementierung neuer Technologien und Geschäftsprozesse effizient gestaltet werden. \nDamit adressiert  APM mehrere Themengebiete, die auch Herausforderungen im Umgang \nmit Cloud -Diensten darstellen.  Der Einsatz dieser Disziplin in diesem Kontext ist bisher \nallerdings weitestgehend unerforscht. Durch die Arbeit soll diese Lücke geschlossen werden. \nDaher ergibt sich folgende Forschungsfrage:   \n \nWelche Risiken und Herausforderungen entstehen bei der Nutzung von Cloud Computing \nund kann Application Portfolio Management diese adressieren?', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 6}),
#  Document(page_content='Einleitung  2 \n Damit verfolgt die Arbeit das Ziel, Application Portfolio Management als mögliche \nHerangehensweise zu identifizieren, sein Potenzial zu erläutern, aber auch Grenzen \naufzuzeigen. Im Laufe der Arbeit wird außerdem ein besonderes Augenmerk auf die \npraktische Anwendbarkeit der gewonnenen Erkenntnisse gelegt. Damit sollen \nHandlungsempfehlungen  für Organisationen abgeleitet werden, um Themen wie Sicherheit \nund Kosten zu optimieren u nd einen Mehrwert durch  Cloud -Transformationen zu e rzielen . \nDie Arbeit soll damit nicht nur zur Erweiterung des theoretischen Wissens beitragen, \nsondern auch einen praxisnahen Beitrag zur Wirtschaftsinformatik leisten.  \nDafür werden im ersten Teil dieser Arbeit zunächst theoretische Grundlagen erklärt. In \nKapitel 2 werden nach einem kurzen Überblick zum Thema Cloud Computing sowie dessen \nAusprägungen auf Basis einer Literaturrecherche die Vorteile, aber insbesondere die R isiken \nund Herausforderungen bei der Nutzung strukturiert erläutert . In Kapitel 3 wird das Konzept \nAPM inklusive seiner Motivation und Ziele beschrieben. Auf Basis dieses Wissens werden \nim Rahmen einer vergleichenden Analyse die zuvor definierten Cloud -Herausforderungen \nden potenziellen Zielen und Ergebnissen von APM gegenübergestellt. Damit soll in der \nTheorie aufgezeigt werden, wie die Anwendung von APM bei der Bewältigung von \nHerausforderungen des Cloud Computing unterstützt.  Anschließend erfolgt die praktische \nErprobung der vorangegangenen theoretischen Analyse in Kapi tel 4. Dafür wird ein EAM -\nTool mit Fokus auf APM im Rahmen einer qualitativen Software evaluation auf seine \nFunktionalität im umrissenen Anwendungsbereich untersucht. Die dabei genutzte \nEvaluations methodik orientiert sich an Arbeiten von Dumslaff et. al. (1994) , Hegner (2023)  \nsowie  Simon et. al. (2010)  und wird in Kapitel 4.2 näher vorgestellt. In der anschließenden \nDiskussion in Kapitel 5 werden die Ergebnisse der Softwareevaluation kritisch bewertet und \nin den Kontext der zuvor erstellten theoretischen Analyse gesetzt. Dafür werden auch \nweitere Herang ehensweisen im Umgang mit Cloud -Risiken und -Herausforderungen \nvorgestellt . Abschließend werden die Inhalte der Arbeit zusammengefasst und die \nForschungsfrage beantwortet.  \nDie wissenschaftliche Disziplin der Wirtschaftsinformatik konzentriert sich darauf, \nsorgfältig zu bewerten, welche Technologien in welche m Kont ext sinnvoll eingesetzt \nwerden können. Diese Bewertung berücksichtigt sowohl die potenziellen Vorteile als auch \nmögliche Herausforderungen, die mit der Nutzung verbunden sind  (Alpar et al., 2023) . Diese \nkritische Analyse und Abwägung soll auch Kerninhalt dieser Arbeit sein.', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 7}),
#  Document(page_content='Cloud Computing  3 \n 2 Cloud Computing  \nIn diesem Kapitel soll zunächst ein kurzer Abriss über theoretische Grundlagen des Cloud \nComputing gegeben werden. Dies er umfasst eine kurze Begriffsdefinition, die Erklärung \nvon Bereitstellungs - und Servicemodellen und eine Einordung in aktuelle technologische \nTrends. D amit wird die Basis für die weitere Arbeit , aber auch für den Rest dieses Kapitels \ngeschaffen , in dem die Vorteile, aber vor allem die Herausforderungen und Risiken bei der \nNutzung von Cloud -Diensten dargestellt werden.  \n2.1 Theoretische Grundlagen und Einordnung  \nLaut Gartner, dem führenden Marktforschungsinstitut für Entwicklungen in der IT, werden \nbis zum Jahre 2026 75% aller Unternehmen ein digitales Transformationsmodell einführen, \nwelches die Cloud als zugrundeliegende Plattform nutzt (DeLisi & Howley, 2023) . Diese \nPrognose zeigt bereits deutlich, welche Rolle das Thema in der Unternehmens - und IT -\nStrategie moderner Unternehmen hat. D as ist keinesfalls verwunderlich in Anbetracht  des \nstetig steigenden Bedarfs an Rechenleistung und Speicherkapazität, um den Anforderungen \naktueller Informationssysteme zu entsprechen. Die flexible und skalierbare Bereitstellung \nvon Hard - und Softwareinfrastruktur durch Cloud Computing stellt einen An satz dar, um \ndiesen Bedarf zu decken (Hentschel & Leyh, 2018) . \n2.1.1  Definition und Abgrenzung  \nDer Begriff wurde erstmals im Jahr 1997 durch Ramnath K. Chellappa auf einer Konferenz \nerwähnt  (Hentschel & Leyh, 2018) . Auch heute gibt es noch keine einheitliche Definition \nfür das Konzept. Die gängigste und weitläufig anerkannteste Definition entstammt dem \nNational Institute of Standards and Technology (NIST). Die NIST bezeichnet  Cloud \nComputing als „model for enabling ubiquitous, convenient, on -demand network access to a \nshared pool of configurable computing resources (e.g., networks, servers, storage, \napplications, and services) that can be rapidly provisioned and released with minimal \nmanagement effort or service prov ider interaction ” (Mell & Grance, 2011, S. 2) . Dabei wird \ndas Konzept durch eine Reihe verschiedener Eigenschaften klassifiziert.  Die Dienste können \nals Self -Service konsumiert werden, sie werden also ohne menschliche Interaktion auf Abruf \nbereitgestellt. Hierbei  basiert die Technologie a uf dem Client -Server -Prinzip, indem die \nFunktionen durch einen Provider über das Internet oder Intranet standortunabhängig \nbereitgestellt werden. Durch die Nutzung eines Multi -Mandanten -Modells können mehrere \nVerbraucher gleichzeitig bedient und Ressourcen dynamisch zugewiesen  werden . Eine \nwichtige Eigenschaft und gleichzeitig ein großer Vorteil liegt in der hohen Elastizität. Die', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 8}),
#  Document(page_content='Cloud Computing  4 \n Ressourcen wie Speicher, Rechenleistung und Services werden je nach Bedarf bereitgestellt \nund freigegeben, um möglichst schnell zu skalieren. Die Nutzung wird dabei permanent \nüberwacht, um sowohl für Anbieter als auch für Anwender  eine hohe Transparenz zu \nschaffen  (Mell & Grance, 2011) . Damit unterscheidet sich Cloud Computing sowohl \ntechnisch als auch wirtschaftlich und organisatorisch von herkömmlichen IT -\nInfrastrukturen. Diese Merkmale werden i n Tabelle 1 näher erläutert . \nTabelle 1: Differenzierungsmerkmale von Cloud -Services gegenüber herkömmlicher IT -Infrastruktur \n(BITKOM, 2009)  \n2.1.2  Ausprägungen von Cloud Computing  \nGrundsätzlich werden Cloud -Dienstleistungen in drei Abstraktionsebenen eingeteilt  und als \nServices bereitgestellt  (Hentschel & Leyh, 2018) . Im Kontext einer serviceorientierten \nArchitektur bezeichnet ein Service dabei eine „abgeschlossene und plattformunabhängig \neinsetzbare Softwarekomponente zur Umsetzung einer fachlichen Funktionalität, die andere \nAnwendungen/Services über eine definierte Sc hnittstelle ansprechen und nutzen können“ \n(Alpar et al., 2023, S. 220) . Die Abstraktionsebenen  ordnen sich in das Everything -as-a-\nService -Paradigma ein (Hentschel & Leyh, 2018) . Die unterste Abstraktionsebene wird als \nInfrastructre -as-a-Service (IaaS) bezeichnet und umfasst Basisinfrastruktur in Form von \nvirtualisierten Servern und Netzwerk -Infrastrukturfunktionalitäten. Die darüberliegende \nEbene stellt IT -Leistungen für Entwick lerplattformen bereit und wird Platform -as-a-Service \n(PaaS) genannt. Mit Hilfe dieser Dienste können System -Architekt en und \nAnwendungsentwickler Anwendungskomponenten entwickeln und integrieren. Unter dem \nBegriff Software -as-a-Service (SaaS) werden in der obersten Ebene standardisierte \nAnwendungen bereitgestellt. Dabei kann über das Internet Software konsumiert werden, \nohne eine Installation durchführen zu müssen. Die Möglichkeiten zur Anpassung und \nIntegration sind dabei aber oft eingeschränkt (BITKOM, 2009) . Merkmal  Erläuterung  \nVollständig virtualisierte \nRessourcen  Nutzer sehen die Services als virtuelle Ressourcen, die physikalische \nRealisierung ist dem Nutzer komplett verborgen. Dies ermöglicht dem \nBetreiber die Optimierung der Infrastruktur hinsichtlich maximaler Effizienz \nund Standardisierung.  \nMulti -Manda ntenfähigkeit  Einzelne Instanzen (Hardware bzw. Software) bedienen in einer \ngemeinsamen genutzten Umgebung viele Nutzer. Dies ist Voraussetzung für \nden Anbieter, um Nutzen aus unterschiedlichen Lastverhalten zu ziehen und \nkostengünstige Angebote für Nutzer zu ermögliche n. \nEchte \nverbrauchsabhängige \nBezahlung  Der Nutzer bezahlt abhängig vom Verbrauch, wobei er gleichmäßig seinen \nVerbrauch gemäß seinem Geschäftsmodell an die aktuellen Erfordernisse \nanpassen kann; dabei kann er beliebig nach oben und unten skalieren .', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 9}),
#  Document(page_content='Cloud Computing  5 \n Neben den Abstraktionsebenen teilt man Cloud -Dienste außerdem in verschiedene \nBetriebsmodelle ein. Eine häufige genutzte Form stellt  die Public Cloud  dar. Die \nInfrastruktur wird dabei von einem Provider für die Öffentlichkeit betrieben und \nbereitgestellt. Bekannte Beispiele dafür sind Amazon Web Services oder Microsoft Azure. \nIm Gegensatz dazu wird eine Private Cloud ausschließlich für eine Organisation betrieben. \nDer Betreiber kann dabei die Organisation selbst, ein Drittanbieter oder eine Kombination \ndieser sein. Eine Community Cloud wird für die ausschließliche Nutzung einer Gruppe \nmehrerer Organisationen bereitgestellt, welche durch ein gemeinsames Anliegen in \nVerbindung zueinander  stehen. Werden mehrere Cloud -Infrastrukturen im Unternehmen \neingesetzt, welche zwar eigenständig betrieben werden, aber eine Schnittstelle für Daten und \nAnwendungen bieten, spricht man von einer Hybrid Cloud (Mell & Grance, 2011) . Wie auch \nin Abbildung 1 dargestellt, können Cloud -Dienste also in verschiedensten Ausprägungen im \nUnternehmen zum Einsatz kommen.  \nAbbildung 1: Ausprägungen von Cloud Computing (in Anlehnung an (Hentschel & Leyh, 2018) ) \n2.1.3  Einordnung in aktuelle Technologietrends  \nDurch die immer stärkere Verbreitung von Cloud Computing ist es heute nicht mehr \nausschließlich für Großunternehmen möglich, große Trendthemen aufzugreifen und \numzusetzen. Die Technologie ist dabei der Katalysator und verändert die Einstellung wie \nUnterneh men darauf reagieren. W ährend bis vor einigen Jahren beispielsweise KI, Industrie \n4.0 und Big Data als hochkomplex, zu teuer und unrealistisch in der Implementierung durch \nkleine IT -Abteilungen angesehen  wurden , spielen sie heute durch Cloud Computing für alle \nOrganisationen eine wichtige Rolle (Hentschel & Leyh, 2018) . Im Folgenden sollen einige \nTrends beispielhaft genannt werden, die derzeit einen großen Einfluss erfahren.  \nEin aktuell wichtiges Thema im Netzwerk - und Netzwerksicherheits -Markt stellt Secure \nAccess Service Edge (SASE) dar. SASE bietet dabei als Architekturkonzept u. a. die', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 10}),
#  Document(page_content='Cloud Computing  6 \n Vorteile, dass der Zugriff auf Daten und Anwendungen stärker kontrolliert werden kann und \ndurch Zero Trust Network Access ein höheres Sicherheitsniveau erreicht wird. Die Lösung \nwird dabei komplett Cloud -basiert bereitgestellt und kann somit auch in kleine ren \nUnternehmen schnell implementiert werden (Schmitz & Luber, 2020) . Gerade in einer Zeit, \nin der es für Mitarbeitende wichtig ist, ihre eigenen Geräte sowohl für private Zwecke als \nauch zum Arbeiten zu nutzen, steigen die Erwartungen und Anforderungen an die zur \nVerfügung gestellte IT -Infrastruktur. Gartner prognostizier t in diesem Zusammenhang, dass \nSASE eine immer größere Bedeutung erfährt, um einen sicheren Zugriff immer und von \nüberall für Nutzende zu ermöglichen (Goasduff, 2022) . \nWeiterhin ist Cloud Computing ein wichtiger Treiber in der Entwicklung von Industrie 4.0 \nin Verbindung mit dem Internet of Things (IoT). IoT bezeichnet dabei das Konzept, sowohl \nphysische als auch virtuelle Objekte durch Sensoren und Schnittstellen miteina nder zu \nvernet zen (Hentschel & Leyh, 2018) . Im Zuge von Industrie 4.0 wird dadurch die Produktion \nflexibler und effizienter  gestaltet , Geschäftsprozesse werden automatisiert und Erzeugnisse \nkönnen durch die Erfassung von Nutzungsdaten verbessert werden (Bundesministerium für \nWirtschaft und Energie, 2019) . Gerade hier schafft Cloud Computing erst die technologische \nGrundlage, um den neuen Anforderungen vor allem durch seine hohe Flexibilität zu \nentsprechen (Hentschel & Leyh, 2018) . \nAll diese Trends finden schließlich auch in der Digitalisierungs - und IT -Strategie von \nUnternehmen Beachtung. Im Zuge der Digitalisierung e rgeben sich  neue Anforderungen. Es \nwird gefordert, dass Daten, Prozesse und Kommunikation uneingeschränkt verfügbar sind \nund neue Funktionalitäten (z. B. Echtzeit -Sendungsverfolgung)  integriert werden . Cloud \nComputing  bietet dafür innovative  Betriebsmodelle wie On-Demand  und as-a-Service, die \neine essentielle  digitale Prozessunterstützung erst möglich machen (Hentschel & Leyh, \n2018) . Es ist daher auch nicht verwunderlich, dass neben traditionellen \nAbstraktionsmodellen auch neue Modelle, wie Business -Platform -as-a-Service, Desktop -as-\na-Service und Security -as-a-Service Einzug erhalten haben (Bataev et al., 2018) . \nIn diesem Kapitel wurde nur ein kleiner Auszug der Themen angesprochen, welche  durch \ndie Technologie einen Aufschwung erfahren. Letztendlich wird der Wandel aber sowohl für \nPrivatpersonen als auch Unternehmen und Organisationen spürbar. DeLisi und Howley  \n(2023)  beschreib en diesen Umstand mit  „Cloud computing is driving the next phase of \ndigital business“. Welche Vorteile die Technologie bietet, um den daraus entstehenden \nHerausforderungen entgegenzuwirken, wird im nächsten Kapitel genauer spezifiziert.', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 11}),
#  Document(page_content='Cloud Computing  7 \n 2.2 Vorteile einer Cloud -zentrierten Anwendungslandschaft  \nAuch wenn der Fokus in dieser Arbeit auf den wesentlichen Risiken und Herausforderungen \neiner Cloud -zentrierten Anwendungslandschaft liegen soll, wird im folgenden Kapitel ein \nAbriss über die wichtigsten Vorteile bei der Nutzung der Technologie geliefert. Ähnlich zu \nHentschel und Leyh (2018) werden die Vorteile im Folgenden aus finanzieller, operat iver \nund strategischer Perspektive betrachtet.  \nTabelle 2: Vorteile der Nutzung von Cloud -Diensten (in Anlehnung an (Hentschel & Leyh, 2018) ) \nBereits aus finanzieller Sicht kann die Nutzung von Cloud -Diensten gegenüber \nherkömmlichen IT -Infrastrukturen große Vorteile bieten. Bei On -Prem -Umgebungen hat \nsich die Ausrichtung von IT -Ressourcen bisher an geschätzten Hochlasten für die Systeme \norientiert. Untersuchungen konnten jedoch  zeigen,  dass die durchschnittlichen Auslastungen \nnur zwischen 10 % und 50% lagen  (Münzl et al., 2015) . Somit wurde ein Großteil der \nvorhandenen Hardware die meiste Zeit nicht genutzt . Für Cloud -Services wird meist \nverbrauchsabhängig bezahlt.  Dieses Kostenmodell wird üblicherweise  „Pay -as-you-go“ \n(PAYG) genannt . Dadurch sinken die Investitionskosten, da die kapitalintensive \nBeschaffung von Hard - und Software entfällt und die Kapitalausgaben durch \nBetriebsausgaben ersetzt  werden (Hentschel & Leyh, 2018) . Durch die Verringerung der \nKapitalbindung wird damit auch die Liquidierbarkeit des Unternehmens weniger \neingeschränkt. Da Cloud -Anbieter Ressourcen bündeln und für eine Vielzahl an Kunden in \nForm identischer On -Demand -Lösungen bereitstellen, kann die Infrastruktur besser \nausgelastet und  günstigere Konditionen mit Zulieferern erreicht werden. Dieser Umstand \nwird als „Economies of Scale “ bezeichnet. Werden diese Effekte weitergereicht, können die \nDienste günstiger genutzt werden  (Hentschel & Leyh, 2018; Metzger et al., 2011) .  Vorteile  \nFinanziell  • Geringere Investitionskosten für IT -Infrastruktur  \n• Verringerung der Kapitalbindung  \n• Niedrigere Betriebs - und Wartungskosten  \nOperativ  • Flexiblere, bedarfsorientierte und agilere Skalierung der IT -Infrastruktur  \n• Schnellere Realisierung von IT -Projekten, auch bei fehlendem Knowhow  \n• Reduzierter Betriebs -, Administrations - und Wartungsaufwand  \n• Ortsunabhängiger Zugriff  \nStrategisch  • Stärkung der Wettbewerbsvorteile und Entwicklung neuer Geschäftsbereiche  \n• Geringere Markteintrittsbarrieren und schnellere „Time to Market“  \n• Standardisierung und Ausrichtung an modernen IT -Lösungen  \n• Stärkung der Fachabteilung durch höhere Verantwortung  \n• Gesteigerte Datensicherheit und bessere Verfügbarkeit von IT -Systemen  \n• Risikotransfer zum Cloudanbieter  \n• Nachhaltigerer Umgang mit Umweltressourcen', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 12}),
#  Document(page_content='Cloud Computing  8 \n Neben den finanziellen Vorteilen können auch operative Gründe für eine Cloud -zentrierte \nAnwendungslandschaft sprechen. Elastizität und Skalierbarkeit von Rechenleistung und \nSpeicherkapazitäten ermöglichen eine wesentlich flexiblere und bedarfsorientierte IT -\nInfrastruktur. Bei temporär auftretendem erhöhtem Bedarf (z. B. durch saisonbedingte \nLastspitzen ) können somit zusätzliche Kapazitäten in Anspruch genommen werden , ohne \nlangfristige Verträge mit Dienstleistern zu verhandeln oder hohe Investitionskosten \naufzunehmen (Hentschel & Leyh, 2018) . Mit der schnellen Bereitstellung von modernen \nTechnologien (v. a. durch PaaS oder SaaS) können IT -Projekte, unterstützt durch den \nFachbereich, wesentlich schneller realisiert werden. Außerdem wird die  Komplexität von \nIT-Infrastrukturen durch die Einführung von Abstraktionsebenen reduziert. Bei SaaS -\nLösungen muss der User Support nicht mehr zwingend inhouse stattfinden. Damit sinken \nder Betriebs -, Administrations - und Wartungsaufwand und die zugehörigen  Kosten. Laut \ndem Marktforschungsinstitut Gartner werd en dafür durchschnittlich zwei Drittel des IT -\nBudgets aufgebraucht . Cloud Computing ermöglicht außerdem die  sofortige weltweite und \nortsunabhängige Einbindung und den Zugriff auf jegliche Systeme. Dadurch kann auch eine \nhöhere Nutzerakzeptanz erreicht werden  (Metzger et al., 2011) . \nDa sich Unternehmen bei der Nutzung von Cloud -Diensten mehr auf ihre Kernaufgaben \nkonzentrieren können anstatt auf die Entwicklung und den Betrieb der IT -Infrastruktur, \nentstehen auch eine Reihe strategischer Vorteile. Anst elle der Entwicklung eigener  \nSoftware lösungen  können beispielsweise SaaS -Dienste  mit hohem Reifegrad genutzt \nwerden . Dadurch können sich Unternehmen  auf die Optimierung von Geschäftsprozessen, \ndie Stärkung gegenüber Wettbewerbern am Markt und die Entwicklung neuer \nGeschäftsbereiche fokussieren (Hentschel & Leyh, 2018) . Der Markt kann durch die \nunmittelbare und flexible Bereitstellung von Ressourcen schnell erreicht, bei Nichterfolg \naber auch schnell wieder verlassen werden. Vor allem k leine und mittelgroße Unternehmen \nerhalten durch Cloud -Services vielfältige Möglichkeiten, da sie ohne signifikante \nInvestitionen auf  moderne  Technologien zugreifen, die früher nur großen Unternehmen zur \nVerfügung standen  (Metzger et al., 2011) . Durch Low -Code -Funktionen und SaaS -Services \nhaben die Fachabteilungen nun eine wesentlich höhere Verantwortung bei  der Auswahl der \neingesetzten IT -Services und können dabei durch ihre fachlichen Kompetenzen unterstützen  \n(Hentschel & Leyh, 2018) . Auch sicherheitsrelevante Themen können strategische Vorteile \nbieten. Einerseits kann d urch verteilte Speichersysteme die Datensicherheit erhöht werden \nund andererseits bewirken redundante Systeme eine erhöhte Verfügbarkeit und \nAusfallsicherheit. Insbesondere in geschäfts - und performancekritischen Bereichen kann die \nNutzung von Cloud Computing somit auch ein Vorteil gegenüber anderen Wettbewerbern', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 13}),
#  Document(page_content='Cloud Computing  9 \n am Markt sein  (Hentschel & Leyh, 2018) . Zusätzlich w ird das Risiko eines Ausfalls und \ndamit verbundene r Schäden durch Service Level Agreements (SLA) an den Betreiber des \nCloud -Dienstes  übertragen (Metzger et al., 2011) . Diese leg en fest, welche Qualität (z. B. in \nForm von Leistung, Verfügbarkeit und Reaktionszeit des Anbieters) durch den \nLeistungsersteller erbracht werden muss  (Siepermann, 2018) . Durch die verbrauchsbedingte \nNutzung kann außerdem der Stromverbrauch gesenkt werden und ein nachhaltigerer \nUmgang mit Umweltressourcen erreicht werden (Shayan et al., 2014) .  \nWie in diesem Kapitel gezeigt wurde,  sprechen eine Vielzahl von Gründen für eine \nTransformation  zu einer Cloud -zentrierten IT -Landschaft. Welche Risiken und \nHerausforderungen trotzdem diesen Wandel hemmen, soll  im Folgenden erklärt werden.  \n2.3 Risiken und Herausforderungen einer Cloud -zentrierten \nAnwendungslandschaft  \nIn der Fachliteratur wird oft von den Vorteilen und Ergebnissen gesprochen, welche  bei der \nNutzung von Cloud Computing eintreten können. Seltener werden allerdings die Risiken \nund Herausforderungen thematisiert, die damit auch entstehen können. Da im späteren \nVerlauf der Arbeit auf Optimierungsansätze eingegangen werden soll, wird hierau f im \nFolgenden auch ein entsprechender Fokus gelegt. Analog zum vorherigen Kapitel wird nach \nfinanziellen, operativen sowie strategischen Risiken und Herausforderungen kategorisiert.  \nTabelle 3: Risiken und Herausforderungen der Nutzung von Cloud -Diensten  \n   Risiken und Herausforderungen  \nFinanziell  • Erhöhte Kosten für Migration von Legacy -Anwendungen  \n• Erhöhte Betriebskosten durch Schatten -IT \n• Kostenentwicklung nicht immer planbar  \nOperativ  • Erhöhter Integrations - und Migrationsaufwand durch fehlende Standards  \n• Unzureichende Interoperabilität zwischen Cloud -Diensten verschiedener \nAnbieter  \n• Compliance -Verstöße  \n• Unkontrollierter Einsatz von Cloud -Diensten und Entstehung von Schatten -IT \n• Risiko bei Netzausfall  \nStrategisch  • Einflussbereich / Einflussmöglichkeiten von Unternehmen sinken  \n• Verlust von Unternehmensgeheimnissen und Missbrauch von Daten durch \nunzureichende Auswahlkriterien bei der Entscheidung für Cloud -Dienste  \n• Abhängigkeit vom Cloud -Dienstleister und Gefahr eines Anbieter Lock -Ins \n• Neue rechtliche Vorgaben', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 14}),
#  Document(page_content='Cloud Computing  10 \n Auch wenn der finanzielle Aspekt stark für einen Cloud -zentrierten Ansatz spricht, gibt es \neinige Hindernisse, welche  die Wirtschaftlichkeit beeinträchtigen können. Gerade die \nMigration von bereits bestehenden Legacy -Applikationen sollte gut geplant sein. Ohne ein \nklares Verständnis über die Anwendung und ihre Abhängigkeiten drohen Verzögerungen \nund Kosten, welche  die aktuellen Betriebskosten übersteigen können. Nicht jede \nAnwendung ist geeignet, um sie in die Cloud zu überführen und ein PAYG -Kostenmodell \nzu nutzen. In einem realen Anwendungsszenario wurde 2021 das Anwendungsportfolio \neiner Bank auf dessen Tauglichk eit untersucht. Dabei waren mit 297 von 350 zwar die \nmeisten aber längst nicht alle Applikationen geeignet, um sie zu überführen (Ramchand et \nal., 2021) . Werden keine Rahmenbedingungen und Regeln im Unternehmen geschaffen, \ndrohen mit dem unkontrollierten Einsatz  von Cloud -Diensten durch den Fachbereich \naußerdem erhöhte Betriebskosten. Diese können dann dafür sorgen, dass Effizienzprojekte, \ndie eigentlich Anwendungen und Infrastruktur konsolidieren sollen und damit Kosten \neinsparen, nichtig gemacht werden  (Münzl et al., 2015) . Weiterhin entsteht vor allem bei \nkleinen Unternehmen das Risiko, dass die zukünftige Kostenentwicklung nicht immer \nplanbar ist (Metzger et al., 2011) .  \nAber auch aus operativer Perspektive werden Unternehmen mit technischen, rechtlichen und \norganisatorischen Herausforderungen konfrontiert. Die Integration unabhängiger (Alt -) \nSysteme kann die zu unterstützenden Unternehmensprozesse beeinträchtigen. Durch \nfehlende Standards zwischen Cloud -Services und bestehenden IT-Systemen kann die \nganzheitliche und performante Unterstützung beeinträchtigt werden  (Hentschel & Leyh, \n2018) . Werden nicht ausreichend Schnittstellen bereitgestellt, stehen Unternehmen vor dem \nRisiko, dauerhaft an einen einzelnen Cloud -Anbieter oder eine spezielle Cloud -Umgebung \ngebunden zu sein. Diese Schnittstellen sollten vor allem der grundlegenden Provisionie rung, \nder Steuerung und Kontrolle der Cloud -Dienste und der Kostenabrechnung entsprechend der \nNutzung dienen. Hier besteht ein dringender Bedarf der Offenheit und Standardisierung  \n(BITKOM, 2013; Hentschel & Leyh, 2018) . Mit Verlagerung des Verantwortungsbereichs \nan Unternehmensexterne müssen Regeln zur Bereitstellung und Nutzung von Cloud -\nServices festgelegt, in der Unternehmensstrategie verankert und eingehalten werden. Nicht \nzuletzt stellt auch die Einhaltung dieser Regeln Unternehmen vor neue Herausforderungen. \nBei Nichteinhaltung drohen strafrechtliche Maßnahmen und Strafzahlungen. Weiterhin \nbegünstigen Compliance -Verstöße und ein unkontrollierte r Einsatz die Bildung von \nSchatten -IT. Die externe Datenhaltung von sensiblen Informationen und die mangelnde \nKontrollfähigkeit stellen signifikante Risikoquellen bei der Nutzung von Cloud -Diensten \ndar. Aufgrund der hohen Konzentration an Daten sind Unternehmen damit ein attraktives', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 15}),
#  Document(page_content='Cloud Computing  11 \n Ziel für Cyberkriminelle  (Hentschel & Leyh, 2018; Münzl et al., 2015) . Somit spielen vor \nallem Datenschutz und Datensicherheit eine große Rolle im so genannten Cloud Controlling  \n(Gärtner & Rockenschaub, 2015) . Ein weiteres technisches Risiko besteht in einem \nNetzausfall. Sollte es zu Störungen mit der Internetverbindung kommen, ist eine Nutzung \nder Cloud -Dienste nicht mehr möglich  (Metzger et al., 2011) . \nAuch strategische Aspekte können ein Risiko darstellen. Werden kritische \nGeschäftsanwendungen in die Cloud bewegt bzw. durch SaaS -Lösungen ersetzt, sinkt der \ndirekte Einflussbereich des Unternehmens. Es werden zwar üblicherweise Updates und neue \nFunktionalitäten geliefert, diese richten sich aber nicht primär n ach den Anforderungen des \neigenen Unternehmens. Die Individualisierung der Cloud -Services ist somit gegenüber \nEigenentwicklungen eingeschränkt , was Wettbewerbsvorteile reduzieren  kann  (BITKOM, \n2009; Hentschel & Leyh, 2018) . Die zentrale Datenhaltung birgt neben den Vorteilen das \nRisiko des Verlusts und Missbrauchs von Unternehmensdaten. Für eine bessere \nDifferenzierbarkeit und Abgrenzung verschiedener Dienstangebote stehen Unternehmen vor \nder Herausforderung, Cloud -Services zu kategorisieren und zu bewerten. Unternehmen \nsollten damit eine kontextabhängige Risikobetrachtung in die Entscheidung einfließen \nlassen  (Hentschel & Leyh, 2018) . Werden Anwendungen in den Fachbereichen kaum noch \nüber interne Infrastruktur genutzt, begibt man sich in eine Abhängigkeit vom Cloud -\nDienstleister. Bei einem Ausfall können somit hohe Kosten entstehen . Die Abhängigkeit in \nVerbindung mit fehlenden Standards zu Anbietern birgt das Risiko eines Anbieter -Lock -Ins \n(Hentschel & Leyh, 2018; Metzger et al., 2011) . Auch rechtliche Regularien müssen bei der \nEntwicklung einer Cloud -Strategie beachtet werden. Da der physische Zugriff auf die \nDatenbestände aufgrund der externen Datenhaltung nicht komplett unter eigener Kontrolle \nsteht, müssen Unternehmen rechtliche Vorgaben beachten, die sich auch auf \nGeschäftsprozesse auswirken können  (BITKOM, 2009) . Im Rahmen der Datenschutz -\nGrundverordnung  können diese zum Beispiel  entstehen, wenn personenbezogene \nUnternehmensdaten  in das Ausland  transferiert werden  (Datenschutz im Rahmen der \nDatenschutz -Grundverordnung , o. J.). \nWie in diesem Kapitel gezeigt wurde,  müssen eine Vielzahl von Themen bei der Nutzung \nbeachtet werden, um die Vorteile nutzen zu können. Die Zusammenarbeit von \nUnternehmensführung, Fachbereich und IT  sowie die Entwicklung einer Cloud -Strategie \nsollten dabei obligatorisch sein, um die Risiken zu minimieren (Hentschel & Leyh, 2018) . \nOb auch APM dazu beitragen kann, wird in den folgenden Kapiteln geklärt.', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 16}),
#  Document(page_content='Application Portfolio Management  12 \n 3 Application Portfolio Management  \nIn dieser Arbeit soll Application Portfolio Management als eine mögliche Herangehensweise \nfür den Umgang mit Cloud -Risiken und -Herausforderungen betrachtet werden. Hierzu wird \nder Begriff in diesem Kapitel zunächst umfangreich hergeleitet, definiert und eingeordnet. \nAnschließend werden Gründe für die Einführung von APM erläutert und dessen Ziele \nerklärt, um es in der Theorie auf die Effektivität im Umgang mit Cloud -Risiken und \nHerausforderungen zu überprüfen.  \n3.1 Theoretische Einführung  \nObwohl moderne Unternehmen nach möglichst integrierten Anwendungen streben, besitzen \nsie in der Realität meist eine Vielzahl verschiedener Applikationen  von verschiedenen \nSoftwareanbietern. H äufig liegt die Anzahl dabei im dreistelligen und nicht selten im \nvierstelligen Bereich (Alpar et al., 2023; Riempp & Gieffers -Ankel, 2007) . Das begründet \nsich vor allem darin, dass Unternehmen immer auf der Suche nach neuen innovativen \nLösungen sind, um am Markt konkurrenzfähig zu bleiben und oftmals gleichzeitig mit \nangespannten wirtschaftlichen Situationen umgehen müssen. In ihrer Funktion  als Business \nEnabler, sind IT -Führungskräfte immer wieder gefordert, die Anforderungen des \nGeschäftsbereichs umzusetzen und neue agile Applikationen zu liefern (Sidhu & Gupta, \n2017) . Dementsprechend  scheint es nicht verwunderlich , dass die Applikationslandschaft \nvieler Unternehmen heutzutage heterogen, intransparent und unüberschaubar groß ist. \nGründe dafür sind neben schnellem Wachstum, in Verbindung mit der Nutzung von Cloud -\nDiensten, z. B. Merger & Acquisition -Szenarien  (Simon et al., 2010) . Dies e sorgen bei den \nFührungskräften für eine enorme Komplexität bei Implementation, Integration, Betrieb und \nWeiterentwicklung von Applikationen (Riempp & Gieffers -Ankel, 2007) . Unnötig hohe \nAusgaben und die mangelhafte Unterstützung von Geschäftsprozessen durch Applikationen \nkönnen die Folge dieser hohen Komplexität in der Anwendungslandschaft sein (Simon et \nal., 2010) . Diese Gründe haben dazu geführt, dass APM in den letzten Jahren immer weiter \nan Bedeutung gewonnen hat. Einen ersten Ansatz für das Erfassen von \nInformationssystemen in einem Portfolio gab  es schon im Jahre 1981 (McFarlan, 1981) . \nAPM ist also keinesfalls ein völlig neues Konzept, sondern wie McKeen und Smith (2010, \nS. 158)  beschreiben, „i t may be one “whose time has come.” “.  \nObwohl die Disziplin in großen Unternehmen in den letzten Jahren immer mehr an \nAufmerksamkeit gewann,  weist die theoretische und akademische Forschung in diesem \nBereich noch größere Lücken auf. Auch Simon  et. al.  (2010, S. 36)  kritisieren : „APM is not \ndefined consistently“ und „publications dealing with APM have made little progress toward', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 17}),
#  Document(page_content='Application Portfolio Management  13 \n achieving an integrated view that encompasses the concept as a whole“. Um die Disziplin \nzu begreifen, werden im folgenden Abschnitt zunächst die zugrundeliegenden Bestandteile \nerläutert.  \nDer Begriff Anwendung (oder Applikation) wird oftmals nur im Zusammenhang mit \nGeschäftsprozessen gesehen, beispielsweise bei Riempp und Gieffers -Ankel (2007, S. 361) , \nwelche Anwendungen  als „summary of functionalities that are closely related to one another \nthrough their shared support of business processes, shared use of information, shared reuse \nand/or shared responsibilities “ definieren . Da Applikationen nicht nur direkt sondern auch \nindirekt auf Geschäftsprozesse einwirken können, beispielsweise unterstützend für eine \nandere Geschäftsanwendung, wird der Term Applikation in dieser Arbeit als \nInformationssystem mit spezifischen Funktionen  definiert , welches Daten als Input erhält, \ndiese verarbeitet und anschließend ausgibt (Sidhu & Gupta, 2017) . Fasst man alle \nApplikationen eines Untersuchungsobjekts (z. B. einer Abteilung, eines Unternehmens oder \neines Unternehmensnetzwerkes) einschließlich ihrer Kommunikationsbeziehungen und \nSchnittstellen zusammen, bilden sie die Anwendungslandschaft (Alpar et al., 2023) . In dieser \nArbeit wird häufig der Begriff Applikationsportfolio verwendet. In der Vergangenheit \nwurden Anwendungen oft nur einzeln betrachtet und deren Zusammenhänge und \nAbhängigkeiten außer Acht gelassen. Dies kann zu Entscheidungen führen, die ineffizient \nsind, die Kosten erhöhen  und nicht  der IT -Strategie folgen. Die Portfolio perspektive wird \nhingegen von McKeen und Smith (2010, S. 159)  als „evaluating new and existing \napplications collectively on an ongoing basis to determine which applications provide value \nto the business in order to support decisions to replace, retire, or further invest in applications \nacross the enterprise“  erklärt . \nWie bereits erwähnt, gibt es keine einheitliche und konsistente wissenschaftliche Definition \nüber den Begriff Application Portfolio Management. Der Begriff wird in der Literatur unter \nverschiedenen Sichtweisen diskutiert.  In den meisten Definitionen wird von einer \nmatrixbasierten Klassifikation oder Analyse entlang verschiedener Kriterien gesprochen. \nBesonders in Bezug auf die Kriterien gibt es allerdings teilweise große Unterschiede. In \neinigen Definitionen wird APM in Ve rbindung mit Quellcodeanalyse gebra cht, in anderen \nDefinitionen wird großer Fokus auf die Betrachtung und Bewertung des wirtschaftlichen \nWerts und der Kosten einer Anwendung gelegt (Simon et al., 2010) . Für den weiteren \nVerlauf dieser Arbeit wird APM daher, orientiert an Simon et. al. (2010), wie folgt definiert:', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 18}),
# ...
#  Document(page_content='Literaturverzeichnis  VI \n Goasduff, L. (2022, November 10). Gartner Says Cloud Will Be the Centerpiece of New \nDigital Experiences . https://www.gartner.com/en/newsroom/press -releases/2021 -\n11-10-gartner -says-cloud -will-be-the-centerpiece -of-new-digital -experiences  \nHegner, M. (2023). Methoden zur Evaluation von Software  (29; IZ -Arbeitsbericht).  \nHentschel, R., & Leyh, C. (2018). Cloud Computing: Status quo, aktuelle Entwicklungen \nund Herausforderungen. In S. Reinheimer (Hrsg.), Cloud Computing: Die \nInfrastruktur der Digitalisierung  (S. 3 –20). Springer Fachmedien Wiesbaden. \nhttps://doi.org/10.1007/978 -3-658-20967 -4_1 \nJhawar, A., van der Heiden, G., Gianni, A., & Frangou, A. (2022, Dezember 12). Magic \nQuadrant for Enterprise Architecture Tools . Gartner. \nhttps://www.gartner.com/doc/reprints?id=1 -\n2C044J8W&ct=221214&st=sb&__hstc=65454513.36a68746676f708506133d7e82\n10c043.1683639448985.1692181810771.1692188207877.18&__hssc=65454513.6.\n1692188207877&__hsfp=2853526177&hsCtaTracking=2eebe9c4 -0394 -40b2 -\n97a8-172669dc744f%7C7284461a -e60f-42ef-9858 -7b418a23dff0  \nKeller, W. (2007). IT-Unternehmensarchitektur: Von der Geschäftsstrategie zur optimalen \nIT-Unterstützung  (1. Aufl). dpunkt. verlag. \nhttps://ebookcentral.proquest.com/lib/leip/reader.action?docID=952261&ppg=1  \nKiesow, A., Langhein, J., & Thomas, O. (2018). Risikoorientiertes Monitoring von Cloud -\nSystemen: Methoden für die externe Revision. In S. Reinheimer (Hrsg.), Cloud \nComputing  (S. 143 –154). Springer Fachmedien Wiesbaden. \nhttps://doi.org/10.1007/978 -3-658-20967 -4_10  \nLeanIX EAM Product Documentation . (o. J.). LeanIX Enterprise Architecture Management. \nAbgerufen 16. August 2023, von https://docs -eam.leanix.net/docs/data -object -\nmodeling  \nLeanIX GmbH (Hrsg.). (2021). Neun typische Anwendungsfälle der Enterprise Architektur . \nhttps://www.leanix.net/de/ty/nine -use-cases -solved -with-enterprise -architecture?  \nLeanIX SMP Product Documentation . (o.  J.). LeanIX SaaS Management Platform. \nAbgerufen 28. September 2023, von https://docs -smp.leanix.net/docs/services  \nMcFarlan, F. W. (1981, September 1). Portfolio Approach to Information Systems. Harvard \nBusiness Review . https://hbr.org/1981/09/portfolio -approach -to-information -\nsystems  \nMcKeen, J. D., & Smith, H. A. (2010). Developments in Practice XXXIV: Application \nPortfolio Management. Communications of the Association for Information Systems , \n26, 158 –170. https://doi.org/10.17705/1CAIS.02609  \nMell, P., & Grance, T. (2011). The NIST definiton of cloud computing  (NIST SP 800 -145; 0 \nAufl.). National Institute of Standards and Technology. \nhttps://doi.org/10.6028/NIST.SP.800 -145 \nMetzger, C., Reitz, T., & Villar, J. (2011). Cloud Computing: Chancen und Risiken aus \ntechnischer und unternehmerischer Sicht . Hanser.  \nMünzl, G., Pauly, M., & Reti, M. (2015). Cloud Computing als neue Herausforderung für \nManagement und IT . Springer Berlin Heidelberg. https://doi.org/10.1007/978 -3-662-\n45832 -7', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 39}),
#  Document(page_content='Literaturverzeichnis  VII \n Ramchand, K., Baruwal Chhetri, M., & Kowalczyk, R. (2021). Enterprise adoption of cloud \ncomputing with application portfolio profiling and application portfolio assessment. \nJournal of Cloud Computing , 10(1), 1. https://doi.org/10.1186/s13677 -020-00210 -w \nRiempp, G., & Gieffers -Ankel, S. (2007). Application portfolio management: A decision -\noriented view of enterprise architecture. Information Systems and e -Business \nManagement , 5(4), 359 –378. https://doi.org/10.1007/s10257 -007-0052 -2 \nSchmitz, P., & Luber, S. (2020, Mai 4). Was ist SASE?  https://www.security -insider.de/was -\nist-sase-a-954025/  \nShayan, J., Azarnik, A., Chuprat, S., Karamizadeh, S., & Alizadeh, M. (2014). Identifying \nBenefits and risks associated with utilizing cloud computing . \nhttps://doi.org/10.7321/jscse.v3.n3.63  \nSidhu, B. S., & Gupta, Dr. K. (2017). Application Portfolio Management: An Approach to \nOvercome IT Management Challenges. International Journal of Trend in Research \nand Development , 3(3), 381 –385. \nSiepermann, D. M. (2018, Februar 19). Definition: Service Level Agreement . \nWirtschaftslexikon Gabler.  https://wirtschaftslexikon.gabler.de/definition/service -\nlevel -agreement -53580/version -276658  \nSimon, D., Fischbach, K., & Schoder, D. (2010). Application Portfolio Management —An \nIntegrated Framework and a Software Tool Evaluation Approach. Communications \nof the Association for Information Systems , 26, 36 –56. \nhttps://doi.org/10.17705/1CAIS.02603  \nVogelezang, F., & Rispens, M. (2007). Application Portfolio Management the basics How \nmuch software do I have . \nWhat is ArchiMate?  (o. J.). LeanIX. Abgerufen 16. August 2023, von \nhttps://www.leanix.net/en/wiki/ea/what -is-archimate?', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 40}),
#  Document(page_content='Anhang  VIII \n Anhang  \nAnhang A: Integriertes APM -Modell  ................................ ................................ ..............  IX \nAnhang B: LeanIX Meta Model v4 inkl. Beziehungen  ................................ ...................  X \nAnhang C: Fragebogen und Evaluationsergebnisse ................................ .......................  XI \nAnhang C.1: Gruppe Informationsumfang  ................................ ................................ ...... XI \nAnhang C.2: Gruppe Funktionsumfang ................................ ................................ .......... XII', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 41}),
#  Document(page_content='Anhang  IX \n Anhang A:  Integriertes APM -Modell  \n(in Anlehnung an (Simon et al., 2010) )', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 42}),
#  Document(page_content='Anhang  X \n Anhang B: LeanIX Meta Model v4  inkl. Beziehungen  \n \n \n(LeanIX EAM Product Documentation, o.  J.)', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 43}),
#  Document(page_content="Anhang  XI \n Anhang C: Fragebogen und Evaluationsergebnisse  \nAnhang C.1: Gruppe Informationsumfang  \n \n  \nSoftwareevaluation\nMetainformationen\nUntersuchungsgegenstand: LeanIX Enterprise Architecture Management Tool\nUntersuchungszeitraum: 14.07.-21.07.2023\nAnbieter: LeanIX\nHauptsitz: Bonn\nInformationsumfang (Entsteht durch die Einbeziehung der Zusatzmodule eine andere Wertung, ist diese in Klammern angegeben)\nWertkriterium Fragestellung0 \n(Eigenschaft ist nicht \ngegeben)1 \n(Eigenschaft ist schwach \nausgeprägt - nur \nähnliche Betrachtung \noder kaum relevant)2 \n(Eigenschaft ist \nmittelmäßig ausgeprägt - \nwird betrachtet, kann \naber nicht in einem hohen \nMaße spezifiziert werden)3 \n(Eigenschaft ist stark \nausgeprägt - wird \nbetrachtet und kann in \nhohem Maße spezifiziert \nwerden)\nBusiness FitBetrachtet das Tool den Business Fit einer Anwendung? Business \nFit meint den Grad, wie stark eine Anwendung den \nGeschäftsbereich unterstützt (die Business Capabilities). X\nBetrachtet das Tool die Geschäftsbereiche, welche durch eine \nAnwendung unterstützt werden?X\nBetrachtet das Tool die Business Kritikalität einer Anwendung? \nBusiness Kritikalität meint in diesem Fall, wie wichtig die \nAnwendung für den Fortführung unternehmenskritischer X\nBetrachtet das Tool die Geschäftsprozesse, welche durch eine \nAnwendung unterstützt werden?X\nTechnical FitBetrachtet das Tool den Technical Fit einer Anwendung? \nTechnical Fit meint den Grad der technischen Reife in der eigenen \nAnwendungslandschaft. X\nBetrachtet das Tool ebenfalls zugrundeliegende \nInfrastrukturkomponenten?X\nRisiken & MehrwerteBetrachtet das Tool spezifische Risiken, die eine Anwendung \nhaben kann? X\nBetrachtet das Tool spezifische Mehrwerte, die eine Anwendung \nhaben kann? X\nBetrachtet das Tool den Business Impact im Rahmen des Business \nContinuity Managements? Business Impact meint in diesem Fall, \nwelchen Einfluss der Ausfall des jeweiligen Systems auf andere \nUnternehmensprozesse darstellt.X\nKostenBetrachtet das Tool die Kosten, die für Einführung und \ninsbesondere Betrieb einer Anwendung aufgewendet werden?X (X)\nBetrachtet das Tool auch variable Kostenmodelle (z. B. Pay-as-\nyou-go bei Cloud-Diensten)?X (X)\nLebenszyklusBetrachtet das Tool die aktuelle Phase innerhalb des \nSoftwarelebenszyklus? X\nBetrachtet das Tool auch den Lebenszyklus der \nInfrastrukturkomponenten (z. B. Aktiver Support, Extended \nSupport, End of Life)? X\nBetrachtet das Tool Informationen, wann der jeweilige \nLebenszyklus endet?X\nBetrachtet das Tool zeitlimitierte Softwarelizenzen? X (X)\nComplianceBetrachtet das Tool Compliance-relevante Informationen, die zur \nEinhaltung gesetzlicher und unternehmensinterner \nBestimmungen relevant sind (Beispiele: Datenschutz, X (X)\nKennzeichnet das Tool Anwendungen, welche mit \nunternehmenskritischen Kundendaten arbeiten?X\nBetrachtet das Tool die SLA's einer Anwendung? X\nVendor InformationenBetrachtet das Tool die Informationen des Vendors einer \nAnwendung, z. B. den Standort? Insbesondere bei SaaS-\nAnwendungen mit Datenhaltung im Ausland können diese \nInformationen relevant sein.X (X)\nAbhängigkeiten Betrachtet das Tool Abhängigkeiten zu anderen Anwendungen? X\nBetrachtet das Tool die Schnittstellen einer Anwendung? X\nBetrachtet das Tool insbesondere Schnittstellen und Standards zu \nanderen Cloud-Anbietern und Hyperscalern?X\nCloud-Dienste Kennzeichnet das Tool Cloud-Anwendungen im speziellen? X\nBerücksichtigt das Tool IaaS- und PaaS-Komponenten? X\nNutzerzahlen und \nNutzergruppenBetrachtet das Tool die Anzahl an Nutzerinnen und Nutzer, die \neine Anwendung nutzen?X\nBetrachtet das Tool die unterschiedlichen Nutzergruppen einer \nAnwendung (Beispiel: unterschiedliche Fachabteilungen)?X\nZugriffBetrachtet das Tool Informationen, wie der Zugriff auf eine \nAnwendung erfolgt (Beispiel: ortsgebunden vs. ortsunabhängig, \nGruppenrichtlinien)X\nESGBetrachtet das Tool ESG-Informationen ...
#  Document(page_content='Anwendung erfolgt (Beispiel: ortsgebunden vs. ortsunabhängig, \nGruppenrichtlinien)X\nESGBetrachtet das Tool ESG-Informationen in Zusammenhang mit \nAnwendungen, z. B. CO2-Werte o. ä.?X\nUpdatesBetrachtet das Tool geplante Updates und Funktionen (insb. bei \nSaaS-Applikationen)?X\nScope FlexibilitätKann das Tool um weitere Attribute erweitert werden, die bei der \nAnalyse von Anwendungen betrachtet werden?XIm Rahmen der Bachelorarbeit: "Optimierung von cloud-zentrierten Anwendungslandschaften durch Application Portfolio Management: Herausforderungen und Lösungen am Beispiel eines Enterprise \nArchitecture Management-Tools"', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 44}),
#  Document(page_content='Anhang  XII \n Anhang C.2: Gruppe Funktionsumfang  \n \n \n \n  \nFunktionsumfang (Entsteht durch die Einbeziehung der Zusatzmodule eine andere Wertung, ist diese in Klammern angegeben)\nWertkriterium Fragestellung0 \n(Eigenschaft ist nicht \ngegeben)1 \n(Eigenschaft ist schwach \nausgeprägt)2 \n(Eigenschaft ist \nmittelmäßig ausgeprägt)3 \n(Eigenschaft ist stark \nausgeprägt)\nNutzerbeteiligungKönnen sich Nutzer der Anwendungen an der Analyse und \nBewertung durch Umfragen beteiligen? X\nSind die Fragen dafür bereits vorkonfiguriert? X\nKönnen die Umfragen angepasst werden? X\nGibt es Automatismen und Benachrichtigungen, um Out-of-Date \nInformationen zu aktualisieren?X\nQualitätssicherungGibt es Mechanismen, um die Qualität der Daten sicherzustellen, \nz. B. Genehmigungsverfahren?X\nQuellcodeanalyseIst das Tool in der Lage, den Quellcode von Anwendungen zu \nanalysieren?X\nKönnen verschiede Programmiersprachen analysiert werden? X\nWerden Änderungen im Quellcode automatisch erfasst? X\nModellierung Können im Tool Modelle manuell erstellt werden? X\nHat die Modellierungsfunktion einen hohen Reifegrad? Hoher \nReifegrad meint in diesem Fall, dass Objekte und ihre \nBeziehungen zueinander so gut beschrieben werden können (z. \nB. durch zusätzliche Attribute), um ein möglichst gutes Abbild der X\nReporting Ist das Tool in der Lage, Reports automatisiert zu erstellen? X\nWerden vorkonfigurierte Reports bereitgestellt? X\nKönnen Reports angepasst werden? X\nKönnen neue Reports ohne großen Aufwand erstellt werden? X\nVerfolgung von historischen \nDatenBesitzt das Tool Versionierungsmechanismen, um historische \nDaten und Änderungen zu erfassen?X\nWerden die historischen Daten automatisiert erfasst? X\nVisualisierung der IT-\nLandschaftIst das Tool in der Lage, die Applikationslandschaft in seiner \nGesamtheit zu visualisieren?X\nIst das Tool in der Lage Multi-Cloud- und Hybrid-Cloud-\nLandschaften darzustellen?X\nKönnen weitere Objekte, z. B. Infrastrukturkomponenten in die \nVisualisierung mit aufgenommen werden, um eine ganzheitliche \nDarstellung der IT-Landschaft zu ermöglichen?X\nPlanung von SzenarienIst das Tool in der Lage, verschiedene Zukunftsszenarien \nabzubilden und zu vergleichen? X\nGibt das Tool eigenständige Verbesserungsvorschläge, die bei der \nEntscheidungsfindung unterstützen?X\nPlanung der IT-LandschaftKann die zukünftige Entwicklung der Anwendungslandschaft \ngeplant werden, z. B. durch zukünftige Versionen eines Objekts?X\nNutzerrollenKönnen verschiedene Nutzerrollen definiert werden, um den \nZugang zu bestimmten Informationen einzuschränken oder \ngeeignete Reports bereitzustellen? X\nWerden vorkonfigurierte Nutzerrollen bereitgestellt? X\nKönnen Nutzerrollen angepasst werden? X\nSchnittstellenKönnen Daten von Microsoft Excel oder ähnlichen Tools \nimportiert und exportiert werden?X\nBesitzt das Tool Schnittstellen (z. B. zu Hyperscalern und \nPlattformdiensten), um Daten automatisiert einzupflegen?X\nIst es mit dem Tool möglich, durch Mechanismismen oder \nKomponenten eigene Schnittstellen zu schaffen?X\nIst das Tool in der Lage, SaaS-Anwendungen zu erkennen und \nautomatisiert zu erfassen?X (X)\nBPMUnterstützt das Tool Business Prozess Management \nFunktionalitäten?X\nPPMUnterstützt das Tool Projekt Portfolio Management \nFunktionalitäten? X', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 45}),
#  Document(page_content='Ehrenwörtliche Erklärung  XIII \n Ehrenwörtliche  Erklärung   \n \n \n________________________    ________________________  \nName, Vorname                   Matrikelnummer  \n \nIch versichere, dass ich die Bachelorarbeit selbstständig  verfasst und keine \nanderen als die angegebenen Quellen und Hilfsmittel benutzt habe.  \n \n \n________________________    ________________________  \nOrt, Datum                   Unterschrift  \n \nSchmohl, Marvin\n3719466\nLeipzig. 29.09.2023', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 46})]

# %%
# Configure the prompt template that is used to ask the LLM

from langchain.prompts import PromptTemplate

template = """
Answer the question based on the context below. If you can't answer the question, reply "I don't know".

Context: {context}

Question: {question}
"""

prompt = PromptTemplate.from_template(template)
print(prompt.format(context="Here is some context", question="Here is a question"))
# Out:
# Answer the question based on the context below. If you can't answer the question, reply "I don't know".
#
# Context: Here is some context
#
# Question: Here is a question

# %%
# Build a LangChain chain containing the prompt and the model

chain = prompt | model 
chain.input_schema.schema()

# %%
# Testing the chain

chain.invoke(
    {
        "context": "My name is Marvin",
        "question": "What is my girlfriends name?"
    }
)
# Out:
# " I don't know, as there is no information provided about your girlfriend in the given context."

# %%
# Use Milvus as Vectorstore

from langchain_community.vectorstores import Milvus

connection_args = {'uri': URI }

vectorstore = Milvus(
    embedding_function=embeddings,
    connection_args=connection_args,
    collection_name=COLLECTION_NAME,
    drop_old=True
).from_documents(
    pages,
    embedding=embeddings,
    collection_name=COLLECTION_NAME,
    connection_args=connection_args
)

# %%
# (Optional) When not using Milvus, this is a simple alternative for a basic vector store

from langchain_community.vectorstores import DocArrayInMemorySearch

vectorstore = DocArrayInMemorySearch.from_documents(
    pages,
    embedding=embeddings
)

# %%
# Do a similarity search for a query

query = "Software Lifecycle"
docs = vectorstore.similarity_search(query)

print(len(docs))
# Out:
# [search] retry:4, cost: 0.27s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:5, cost: 0.81s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:6, cost: 2.43s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:7, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B::1%5D:19530: Failed to connect to remote host: Connection refused>
# [search] retry:8, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:9, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:10, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:11, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:12, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# 4

# %%
# Test by using the vectorstore as a retriever. The retriever gives back the relevant pages based on the query invoked

retriever = vectorstore.as_retriever()

retriever.invoke("LeanIX")
# Out:
# [search] retry:4, cost: 0.27s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:5, cost: 0.81s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:6, cost: 2.43s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:7, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:8, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:9, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:10, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [search] retry:11, cost: 3.00s, reason: <_InactiveRpcError: StatusCode.UNAVAILABLE, failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:19530: Failed to connect to remote host: Connection refused>
# [Document(page_content='Abkürzungsverzeichnis  IV \n Abkürzungsverzeichnis  \nAPM  Application Portfolio Management  \nCCCC  Cloud Computing Considerations for Companies  \nEAM  Enterprise Architecture Management  \nEOL  End-of-Life \nESG  Environmental, Social and Governance  \nIaaS Infrastructure -as-a-Service \nIoT Internet of Things  \nNIST  National Institute of Standards and Technology  \nPaaS  Platform -as-a-Service  \nPAYG  Pay-as-you-go \nSaaS  Software -as-a-Service  \nSASE  Secure Access Service Edge  \nSLA  Service Level Agreement  \nSMP  SaaS  Management  Platform  \nTRM  Technology Risk Management', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 5, 'pk': 450076633657247765}),
#  Document(page_content='Literaturverzeichnis  VI \n Goasduff, L. (2022, November 10). Gartner Says Cloud Will Be the Centerpiece of New \nDigital Experiences . https://www.gartner.com/en/newsroom/press -releases/2021 -\n11-10-gartner -says-cloud -will-be-the-centerpiece -of-new-digital -experiences  \nHegner, M. (2023). Methoden zur Evaluation von Software  (29; IZ -Arbeitsbericht).  \nHentschel, R., & Leyh, C. (2018). Cloud Computing: Status quo, aktuelle Entwicklungen \nund Herausforderungen. In S. Reinheimer (Hrsg.), Cloud Computing: Die \nInfrastruktur der Digitalisierung  (S. 3 –20). Springer Fachmedien Wiesbaden. \nhttps://doi.org/10.1007/978 -3-658-20967 -4_1 \nJhawar, A., van der Heiden, G., Gianni, A., & Frangou, A. (2022, Dezember 12). Magic \nQuadrant for Enterprise Architecture Tools . Gartner. \nhttps://www.gartner.com/doc/reprints?id=1 -\n2C044J8W&ct=221214&st=sb&__hstc=65454513.36a68746676f708506133d7e82\n10c043.1683639448985.1692181810771.1692188207877.18&__hssc=65454513.6.\n1692188207877&__hsfp=2853526177&hsCtaTracking=2eebe9c4 -0394 -40b2 -\n97a8-172669dc744f%7C7284461a -e60f-42ef-9858 -7b418a23dff0  \nKeller, W. (2007). IT-Unternehmensarchitektur: Von der Geschäftsstrategie zur optimalen \nIT-Unterstützung  (1. Aufl). dpunkt. verlag. \nhttps://ebookcentral.proquest.com/lib/leip/reader.action?docID=952261&ppg=1  \nKiesow, A., Langhein, J., & Thomas, O. (2018). Risikoorientiertes Monitoring von Cloud -\nSystemen: Methoden für die externe Revision. In S. Reinheimer (Hrsg.), Cloud \nComputing  (S. 143 –154). Springer Fachmedien Wiesbaden. \nhttps://doi.org/10.1007/978 -3-658-20967 -4_10  \nLeanIX EAM Product Documentation . (o. J.). LeanIX Enterprise Architecture Management. \nAbgerufen 16. August 2023, von https://docs -eam.leanix.net/docs/data -object -\nmodeling  \nLeanIX GmbH (Hrsg.). (2021). Neun typische Anwendungsfälle der Enterprise Architektur . \nhttps://www.leanix.net/de/ty/nine -use-cases -solved -with-enterprise -architecture?  \nLeanIX SMP Product Documentation . (o.  J.). LeanIX SaaS Management Platform. \nAbgerufen 28. September 2023, von https://docs -smp.leanix.net/docs/services  \nMcFarlan, F. W. (1981, September 1). Portfolio Approach to Information Systems. Harvard \nBusiness Review . https://hbr.org/1981/09/portfolio -approach -to-information -\nsystems  \nMcKeen, J. D., & Smith, H. A. (2010). Developments in Practice XXXIV: Application \nPortfolio Management. Communications of the Association for Information Systems , \n26, 158 –170. https://doi.org/10.17705/1CAIS.02609  \nMell, P., & Grance, T. (2011). The NIST definiton of cloud computing  (NIST SP 800 -145; 0 \nAufl.). National Institute of Standards and Technology. \nhttps://doi.org/10.6028/NIST.SP.800 -145 \nMetzger, C., Reitz, T., & Villar, J. (2011). Cloud Computing: Chancen und Risiken aus \ntechnischer und unternehmerischer Sicht . Hanser.  \nMünzl, G., Pauly, M., & Reti, M. (2015). Cloud Computing als neue Herausforderung für \nManagement und IT . Springer Berlin Heidelberg. https://doi.org/10.1007/978 -3-662-\n45832 -7', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 39, 'pk': 450076633657247799}),
#  Document(page_content='Gliederung  I \nGliederung  \nGliederung  ................................ ................................ ................................ ............................. I \nAbbildungsverzeichnis  ................................ ................................ ................................ ....... II \nTabellenverzeichnis  ................................ ................................ ................................ ..........  III \nAbkürzungsverzeichnis  ................................ ................................ ................................ ..... IV \n1 Einleitung  ................................ ................................ ................................ .....................  1 \n2 Cloud Computing  ................................ ................................ ................................ ........  3 \n2.1 Theoretische Grundlagen und Einordnung  ................................ ................................  3 \n2.1.1 Definition und Abgrenzung  ................................ ................................ ................................ ........  3 \n2.1.2 Ausprägungen von Cloud Computing  ................................ ................................ ........................  4 \n2.1.3 Einordnung in aktuelle Technologietrends  ................................ ................................ .................  5 \n2.2 Vorteile einer Cloud -zentrierten Anwendungslandschaft  ................................ .........  7 \n2.3 Risiken und Herausforderungen einer Cloud -zentrierten Anwendungslandschaft  ... 9 \n3 Application Portfolio Management  ................................ ................................ ..........  12 \n3.1 Theoretische Einführung  ................................ ................................ .........................  12 \n3.2 Einordnung  ................................ ................................ ................................ ..............  14 \n3.3 Gründe für die Einführung von APM  ................................ ................................ ...... 15 \n3.4 Ziele und Ergebnisse von Application Portfolio Management  ...............................  16 \n3.5 Anwendung von Application Portfolio Management zur Bewältigung von Risiken \nund Herausforderungen bei der Nutzung von Cloud -Diensten  ................................ ....... 18 \n4 Praktische Anwendung des Ansatzes  ................................ ................................ ....... 20 \n4.1 Vorstellung des Untersuchungsgegenstands  ................................ ...........................  20 \n4.2 Vorstellung des Evaluationsansatzes  ................................ ................................ ....... 22 \n4.3 Ergebnisse der Evaluation  ................................ ................................ .......................  24 \n4.4 Bewertung der Wirksamkeit des Ansatzes  ................................ ..............................  26 \n5 Diskussion  ................................ ................................ ................................ ...................  27 \n5.1 Diskussion der Ergebnisse  ................................ ................................ .......................  27 \n5.2 Weitere Lösungsansätze  ................................ ................................ ..........................  30 \n6 Fazit ................................ ................................ ................................ .............................  31 \nLiteraturverzeichnis  ................................ ................................ ................................ ...........  V \nAnhang  ................................ ................................ ................................ ............................. VIII  \nEhrenwörtliche Erklärung ................................ ................................ ............................. XIII', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandscha ...
#  Document(page_content='Tabellenverzeichnis  III \n Tabellenverzeichnis  \nTabelle 1: Differenzierungsmerkmale von Cloud -Services gegenüber herkömmlicher IT -\nInfrastruktur  ................................ ................................ ................................ ...................  4 \nTabelle 2: Vorteile der Nutzung von Cloud -Diensten  ................................ ...........................  7 \nTabelle 3: Risiken und Herausforderungen der Nutzung von Cloud -Diensten  .....................  9 \nTabelle 4: Unterstützung bei Cloud -Risiken durch APM  ................................ ...................  19 \nTabelle 5: Prozessschritte bei der Softwareevaluation  ................................ ........................  23', metadata={'source': 'Optimierung Cloud-zentrierter Anwendungslandschaften durch Application Portfolio Management.pdf', 'page': 4, 'pk': 450076633657247764})]

# %%
# Build a chain additionally context information from the Vector database

from operator import itemgetter
chain = (
    {
        "context": itemgetter("question") | retriever, 
        "question": itemgetter("question")
    }
    | prompt 
    | model
)

print(chain.invoke({"question": "Was ist LeanIX?"}))
# Out:
#  LeanIX ist kein direkt erwähnter Begriff in den angezeigten Texten. Es scheint sich um eine Software zur Application Portfolio Management (APM) zu handeln, die helfen kann, die Anwendungslandschaft einer Organisation von einer Portfolioperspektive aus anzusehen und zu analysieren. LeanIX ist eine Marke für das Unternehmen LeanIX AG, das Software-as-a-Service (SaaS) anbietet, um Anwendungsportfolios effizienter und transparenter zu verwalten.

# %%
# Alternative way to print the result so every character is printed single in a stream as in ChatGPT

for s in chain.stream({"question": "Was ist Cloud Computing?"}):
    print(s, end="", flush=True)
# Out:
#  Cloud Computing ist ein Dienst, bei dem Rechenleistung, Speicherkapazität und IT-Dienste über das Internet bereitgestellt werden. Es bietet Vorteile wie Kosteneffizienz, hohe Flexibilität und Skalierbarkeit sowie den Zugang zu neuen Technologien. Allerdings gibt es auch Risiken und Herausforderungen bei der Nutzung von Cloud Computing, z.B. bei Datenschutz, Netzausfall, strategischen Aspekten, Abhängigkeit vom Dienstleister, Anbieter-Lock-Ins und rechtlichen Regularien. Um die Vorteile nutzen zu können und Risiken zu minimieren sollte es eine Zusammenarbeit zwischen Unternehmensführung, Fachbereich und IT geben sowie die Entwicklung einer Cloud-Strategie.
